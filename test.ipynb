# %%
print("test")
# Out:
# test

# %%
from src.configs.get_config import get_config


constraints_config = get_config("constraints_config")


true_constraints = [
    key for key, value in constraints_config.items() if value.get("included")
]
constraints
# Out:
# ['each_group_max_once_per_week',
#  'only_schedule_groups_when_they_are_available',
#  'each_educator_max_once_per_time_slot']

# %%
group_time_teacher_availability = {}
groups = ["school_1", "school_2", "school_3"]
time_slots = ["mon_1", "mon_2", "mon_3"]
teachers = ["Floris", "Thomas", "Nils"]

for group in groups:
    for time_slot in time_slots:
        for teacher in teachers:
            group_time_teacher_availability[(group, time_slot, teacher)] = 0


# group_time_teacher_availability[("school_1", "Floris", "mon_3")]
group_time_teacher_availability
# Out:
# {('school_1', 'Floris', 'mon_1'): 0,
#  ('school_1', 'Floris', 'mon_2'): 0,
#  ('school_1', 'Floris', 'mon_3'): 0,
#  ('school_1', 'Thomas', 'mon_1'): 0,
#  ('school_1', 'Thomas', 'mon_2'): 0,
#  ('school_1', 'Thomas', 'mon_3'): 0,
#  ('school_1', 'Nils', 'mon_1'): 0,
#  ('school_1', 'Nils', 'mon_2'): 0,
#  ('school_1', 'Nils', 'mon_3'): 0,
#  ('school_2', 'Floris', 'mon_1'): 0,
#  ('school_2', 'Floris', 'mon_2'): 0,
#  ('school_2', 'Floris', 'mon_3'): 0,
#  ('school_2', 'Thomas', 'mon_1'): 0,
#  ('school_2', 'Thomas', 'mon_2'): 0,
#  ('school_2', 'Thomas', 'mon_3'): 0,
#  ('school_2', 'Nils', 'mon_1'): 0,
#  ('school_2', 'Nils', 'mon_2'): 0,
#  ('school_2', 'Nils', 'mon_3'): 0,
#  ('school_3', 'Floris', 'mon_1'): 0,
#  ('school_3', 'Floris', 'mon_2'): 0,
#  ('school_3', 'Floris', 'mon_3'): 0,
#  ('school_3', 'Thomas', 'mon_1'): 0,
#  ('school_3', 'Thomas', 'mon_2'): 0,
#  ('school_3', 'Thomas', 'mon_3'): 0,
#  ('school_3', 'Nils', 'mon_1'): 0,
#  ('school_3', 'Nils', 'mon_2'): 0,
#  ('school_3', 'Nils', 'mon_3'): 0}
